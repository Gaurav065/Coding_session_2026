# %%
a = [1,2,3,3,4,4,4,5]

# %%
del(set)

# %%
b = tuple(a)

# %%
b = set(b)

# %%
b
# Out:
# {1, 2, 3, 4, 5}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 b = map(1,2,3,3,3,3,3,3,3,)
#
# TypeError: 'int' object is not iterable

# %%
b.put(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 b.put(a)
#
# AttributeError: 'map' object has no attribute 'put'

# %%
c = {1,1,2,3,4,5,6,7,7,8}

# %%
c
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
